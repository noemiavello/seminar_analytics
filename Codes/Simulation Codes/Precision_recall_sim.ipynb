# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
sim_data = pd.read_csv("/content/drive/MyDrive/R/paper/sim_data.csv")
print(sim_data)
# Out:
#              x  y       cep
# 0     0.287578  1  0.536263
# 1     0.788305  1  0.887865
# 2     0.408977  0  0.639513
# 3     0.883017  1  0.939690
# 4     0.940467  1  0.969777
# ...        ... ..       ...
# 9995  0.466352  1  0.682900
# 9996  0.898952  1  0.948131
# 9997  0.113535  0  0.336949
# 9998  0.571226  1  0.755795
# 9999  0.900585  1  0.948992
#
# [10000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.isotonic import IsotonicRegression
from sklearn.datasets import make_regression

X = sim_data.x
y = sim_data.y

iso_reg = IsotonicRegression().fit(X, y)

iso_reg.predict([.1, .2])
# Out:
# array([0.30612245, 0.45348837])

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# X, y = make_classification(random_state=0)
# X_train, X_test, y_train, y_test = train_test_split(
#         X, y, random_state=0)
# clf = LogisticRegression()
# clf.fit(X_train, y_train)
# y_pred = clf.predict_proba(X_test)[:, 1]

# %%
PrecisionRecallDisplay.from_predictions(
   sim_data.y, sim_data.cep )
plt.xlabel('Recall')
plt.ylabel('Precision')
# plt.show()
from google.colab import files
plt.savefig("Precision_recall_sim.pdf")
files.download("Precision_recall_sim.pdf")
